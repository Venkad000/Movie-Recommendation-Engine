# %%
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt

# %%
movie_df = pd.read_csv("movie.csv")
movie_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
rating_df = pd.read_csv("rating.csv")
rating_df = rating_df.drop('timestamp', axis=1)
rating_df.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
tag_df = pd.read_csv("tag.csv")
tag_df = tag_df.drop("timestamp", axis = 1)
tag_df.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
genome_scores_df = pd.read_csv("genome_scores.csv")
genome_scores_df.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675

# %%
genome_tags_df = pd.read_csv("genome_tags.csv")
genome_tags_df.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
links_df = pd.read_csv("link.csv")
links_df.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
len(rating_df)
# Out:
# 20000263

# %%
new_rating_df = rating_df.truncate(after=10000)

# %%
len(new_rating_df)
# Out:
# 10001

# %%
# number of unique users
len(rating_df["userId"].unique())
# Out:
# 138493

# %%
len(movie_df)
# Out:
# 27278

# %%
usersrating = [[0.0] * max(movie_df["movieId"])] * (max(rating_df["userId"]))

# %%
max(movie_df["movieId"]), max(rating_df["userId"])
# Out:
# (131262, 138493)

# %%
rating_df = rating_df.sample(frac=1)
rating_df.head()
# Out:
#           userId  movieId  rating
# 14757026  101963     1956     4.0
# 6902721    47558     3421     3.0
# 15860677  109735     4572     4.0
# 1798570    12143     2628     3.5
# 5360370    36793      231     4.0

# %%
for i in range(0, 10000):
    uid = int(rating_df.iloc[i]["userId"])
    movid = int(rating_df.iloc[i]["movieId"])
    rating = rating_df.iloc[i]["rating"]
    # print(uid, movid, rating)
    usersrating[uid-1][movid-1] = rating
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 3
#       1 for i in range(0, 20000263):
#       2     uid = int(rating_df.iloc[i]["userId"])
# ----> 3     movid = int(rating_df.iloc[i]["movieId"])
#       4     rating = rating_df.iloc[i]["rating"]
#       5     # print(uid, movid, rating)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexing.py:1754, in _iLocIndexer._getitem_axis(self, key, axis)
#    1751 # validate the location
#    1752 self._validate_integer(key, axis)
# -> 1754 return self.obj._ixs(key, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:3984, in DataFrame._ixs(self, i, axis)
#    3982 # irow
#    3983 if axis == 0:
# -> 3984     new_mgr = self._mgr.fast_xs(i)
#    3986     # if we are a copy, mark as such
#    3987     copy = isinstance(new_mgr.array, np.ndarray) and new_mgr.array.base is None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\managers.py:984, in BlockManager.fast_xs(self, loc)
#     976     block = new_block(
#     977         result,
#     978         placement=bp,
#     979         ndim=1,
#     980         refs=self.blocks[0].refs,
#     981     )
#     982     return SingleBlockManager(block, self.axes[0])
# --> 984 dtype = interleaved_dtype([blk.dtype for blk in self.blocks])
#     986 n = len(self)
#     988 if isinstance(dtype, ExtensionDtype):
#     989     # TODO: use object dtype as workaround for non-performant
#     990     #  EA.__setitem__ methods. (primarily ArrowExtensionArray.__setitem__
#     991     #  when iteratively setting individual values)
#     992     #  https://github.com/pandas-dev/pandas/pull/54508#issuecomment-1675827918
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\internals\base.py:394, in interleaved_dtype(dtypes)
#     391 if not len(dtypes):
#     392     return None
# --> 394 return find_common_type(dtypes)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\dtypes\cast.py:1461, in find_common_type(types)
#    1458     return first
#    1460 # get unique types (dict.fromkeys is used as order-preserving set())
# -> 1461 types = list(dict.fromkeys(types).keys())
#    1463 if any(isinstance(t, ExtensionDtype) for t in types):
#    1464     for t in types:
#
# KeyboardInterrupt:

# %%
userSimMatrix = [[0] * (max(rating_df["userId"]))] * (max(rating_df["userId"]))

# %%
def cosine_sim(a, b):
    crossprod = 0.0
    maga = 0.0
    magb = 0.0
    for i in len(0, len(a)):
        crossprod += a[i] * b[i]
        maga += a[i] * a[i]
        magb += b[i] * b[i]
    return crossprod / ((maga)**0.5 * (magb)**0.5)

# %%
for i in range(0, max(rating_df["userId"])):
    userSimMatrix[i][i] = 1

# %%
for i in range(0, (max(rating_df["userId"]))):
    for j in range(0, i+1):
        userSimMatrix[i][j] = cosine_sim(usersrating[i], usersrating[j])

# %%
X = np.array(userSimMatrix)
wcss = []
for i in range(1, 13):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
tag=pd.read_csv('tag.csv')
rating=pd.read_csv('rating.csv')
movies=pd.read_csv('movie.csv')
genome_scores=pd.read_csv('genome_scores.csv')
link=pd.read_csv('link.csv')
genome_tag=pd.read_csv('genome_tags.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
link.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
rating.shape
# Out:
# (20000263, 4)

# %%
rating['userId'].value_counts().shape ## unique users
# Out:
# (138493,)

# %%
x=rating['userId'].value_counts()>500

# %%
y = x[x].index

# %%
y.shape
# Out:
# (7441,)

# %%
rating=rating[rating['userId'].isin(y)]

# %%
rating.shape
# Out:
# (6554416, 4)

# %%
movie_details=movies.merge(rating,on='movieId')

# %%
movie_details.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating            timestamp
# 0      11     4.5  2009-01-02 01:13:41
# 1      24     4.0  2001-07-04 07:02:29
# 2      54     4.0  2000-11-21 21:00:21
# 3      58     5.0  2006-04-03 10:00:08
# 4      91     4.0  2005-03-22 22:46:02

# %%
movie_details.drop(columns=['timestamp'],inplace=True)

# %%
movie_details.shape
# Out:
# (6554416, 5)

# %%
movie_details.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating
# 0      11     4.5
# 1      24     4.0
# 2      54     4.0
# 3      58     5.0
# 4      91     4.0

# %%
number_rating = movie_details.groupby('title')['rating'].count().reset_index()

# %%
number_rating.rename(columns={'rating':'number of rating'},inplace=True)

# %%
df=movie_details.merge(number_rating,on='title')

# %%
df=df[df['number of rating']>=50] #selecting valuable books by ratings

# %%
number_rating.head()
# Out:
#                                                title  number of rating
# 0  #chicagoGirl: The Social Network Takes on a Di...                 2
# 1                                 $ (Dollars) (1971)                 7
# 2                                    $5 a Day (2008)                10
# 3                                       $9.99 (2008)                17
# 4                     $ellebrity (Sellebrity) (2012)                 1

# %%
df=movie_details.merge(number_rating,on='title')

# %%
df=df[df['number of rating']>=50] #selecting valuable books by ratings

# %%
df.drop_duplicates(['title','userId'],inplace=True)

# %%
df.drop(columns=['number of rating'],inplace=True)

# %%
df['rating']=df['rating'].astype(int)

# %%
movie_pivot=df.pivot_table(columns='userId',index='title',values='rating')

# %%
movie_pivot.fillna(0,inplace=True)

# %%
movie_pivot
# Out:
# userId                                         11      24      54      58      \
# title
# 'Round Midnight (1986)                            0.0     0.0     0.0     0.0
# 'Til There Was You (1997)                         0.0     0.0     0.0     0.0
# 'burbs, The (1989)                                0.0     0.0     3.0     0.0
# 'night Mother (1986)                              0.0     0.0     0.0     0.0
# (500) Days of Summer (2009)                       0.0     0.0     0.0     0.0
# ...                                               ...     ...     ...     ...
# loudQUIETloud: A Film About the Pixies (2006)     0.0     0.0     0.0     0.0
# userId                                         138474
# title
# 'Round Midnight (1986)                            0.0
# 'Til There Was You (1997)                         0.0
# 'burbs, The (1989)                                4.0
# 'night Mother (1986)                              0.0
# (500) Days of Summer (2009)                       0.0
# ...                                               ...
# loudQUIETloud: A Film About the Pixies (2006)     0.0
# xXx (2002)                                        0.0
# xXx: State of the Union (2005)                    0.0
# ¡Three Amigos! (1986)                             0.0
# À nous la liberté (Freedom for Us) (1931)         0.0
#
# [9359 rows x 7441 columns]

# %%
# !pip install scipy
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in c:\users\venka\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.13.0)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\venka\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scipy) (1.26.4)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\venka\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\venka\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.13.0)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.4.2-cp312-cp312-win_amd64.whl (10.6 MB)
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB 991.0 kB/s eta 0:00:11
#    - -------------------------------------- 0.4/10.6 MB 5.5 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/10.6 MB 7.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.4/10.6 MB 8.1 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/10.6 MB 8.2 MB/s eta 0:00:02
#    -------- ------------------------------- 2.2/10.6 MB 8.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.8/10.6 MB 9.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.2/10.6 MB 9.2 MB/s eta 0:00:01
#    ------------- -------------------------- 3.5/10.6 MB 8.9 MB/s eta 0:00:01
#    --------------- ------------------------ 4.0/10.6 MB 9.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.5/10.6 MB 9.3 MB/s eta 0:00:01
#    ------------------ --------------------- 4.9/10.6 MB 9.2 MB/s eta 0:00:01
#    -------------------- ------------------- 5.3/10.6 MB 9.4 MB/s eta 0:00:01
#    --------------------- ------------------ 5.7/10.6 MB 9.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.9/10.6 MB 9.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.3/10.6 MB 9.4 MB/s eta 0:00:01
#    ------------------------ --------------- 6.6/10.6 MB 8.7 MB/s eta 0:00:01
#    -------------------------- ------------- 6.9/10.6 MB 8.9 MB/s eta 0:00:01
#    --------------------------- ------------ 7.2/10.6 MB 8.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.6/10.6 MB 8.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.9/10.6 MB 8.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.2/10.6 MB 8.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.4/10.6 MB 8.6 MB/s eta 0:00:01
#    -------------------------------- ------- 8.6/10.6 MB 8.5 MB/s eta 0:00:01
#    --------------------------------- ------ 8.9/10.6 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.2/10.6 MB 8.5 MB/s eta 0:00:01
#    ------------------------------------ --- 9.6/10.6 MB 8.6 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.6 MB 8.6 MB/s eta 0:00:01
#    -------------------------------------- - 10.3/10.6 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------  10.6/10.6 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 10.6/10.6 MB 8.7 MB/s eta 0:00:00
# Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.2 kB ? eta -:--:--
#    ---------------------------------------- 301.2/301.2 kB 9.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.0 scikit-learn-1.4.2 threadpoolctl-3.4.0

# %%
from scipy.sparse import csr_matrix
movie_sparse=csr_matrix(movie_pivot)

# %%
from sklearn.neighbors import NearestNeighbors
model=NearestNeighbors( n_neighbors=7,algorithm='brute',metric='cosine')

# %%
model.fit(movie_sparse)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=7)

# %%
df.drop(columns=['genres','userId','rating'],inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.to_csv('codf.csv',index=False)

# %%
distances,suggestions=model.kneighbors(movie_pivot.iloc[540,:].values.reshape(1,-1))

# %%
distances
# Out:
# array([[4.44089210e-16, 7.42246328e-01, 7.57713782e-01, 7.70884163e-01,
#         7.90774536e-01, 7.93849736e-01, 7.93911073e-01]])

# %%
suggestions
# Out:
# array([[ 540, 6149, 8407, 3888,  672, 6732, 6057]], dtype=int64)

# %%
df1=df.copy()
ti=[]
for i in df1['title']:
    ti.append(i.split(' (')[0])
df1['title']=ti

# %%
for i in range(len(suggestions)):
    print(movie_pivot.index[suggestions[i]])
# Out:
# Index(['Article 99 (1992)', 'One Good Cop (1991)', 'Thunderheart (1992)',
#        'Hooper (1978)', 'Bad Influence (1990)', 'Q & A (1990)', 'Nuts (1987)'],
#       dtype='object', name='title')

# %%
def reco(movie_name):
    movie_id=df1[df1['title']=='Toy Story'].drop_duplicates('title')['movieId'].values[0]
    distances,suggestions=model.kneighbors(movie_pivot.iloc[movie_id,:].values.reshape(1,-1))   
    for i in range(len(suggestions)):
        return (movie_pivot.index[suggestions[i]])

# %%
print(reco("Earthquake (1974)"))
# Out:
# Index([''Til There Was You (1997)', 'MatchMaker, The (1997)',
#        'Evening Star, The (1996)', 'To Gillian on Her 37th Birthday (1996)',
#        'Only You (1994)', 'Mrs. Winterbourne (1996)',
#        'Picture Perfect (1997)'],
#       dtype='object', name='title')
